# %% [markdown]
# <a href="https://colab.research.google.com/github/cannoncg/gis-project-portfolio-geo441c/blob/main/GEO441_541_Week1_Cannon_Cassie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO441/541C Week 1 Assignment: Introduction to ArcGIS Pro GUI**

# %% [markdown]
# Created by Cassie Cannon
# 1/30/2026

# %% [markdown]
# ### **Create my first map using ArcGIS Pro**
#
#
#
#   The default link I get for this PNG file is listed below but it cannot be directly used in Notebook to show the picture correctly
#
# https://drive.google.com/file/d/1SXPpTnp055ru1Md_GDCsmVZC8QfRC6J-/view?usp=drive_link
#
#   - I made some changes to the default sharable link:
#     - Keep the **`1A2B3C4D5E6F7G8H9I0J`** part because this is the unique file ID for the picture
#     - Deleted **`/view?usp=sharing`** at the end of the link
#     - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#
#   The link below is the correct one I need to use in the next section
#
# https://drive.google.com/uc?export=view&id=1SXPpTnp055ru1Md_GDCsmVZC8QfRC6J-
#
#
# **Map:**
#
#  ![map](https://drive.google.com/uc?export=view&id=1SXPpTnp055ru1Md_GDCsmVZC8QfRC6J-)
# <!-- Example Image Placeholder -->

# %% [markdown]
# ### **Reflection on my first experience with ArcGIS Pro**
#
# - Overall, I spent 2 hours to finish creating my first map
# - Here is a table showing things that I feel excited and challenging in my first experience working in ArcGIS Pro
#
# | Things I'm excited about      | Things challenging for me  |
# | ----------------------------- | -------------------------- |
# | Using more raster data     | Sizing and format of the map during the layout  |
# | Learning more about the Attribute Table and its purpose     | Design and properties in the layout portion    |
# | Finding our own data to apply to maps      | Sorting and organization of files   |
#
# - Here is how I rate my first experience working in ArcGIS Pro
#   - Data important and management
#     - Downloading and finding the data was pretty simple in terms of acessing it on ArcGIS. I had some concerns if we are only saving our data and maps to our Data folder that I would be only able to access this on one specific computer. I don't want it to disappear, and didn't know if there was a possibility to keep it on a personal drive and if so where.
#   - Map creation and annotation
#     - Creating the map itself was easy once I had the directions to follow. It was cool to be able to change use the symbology to change some aspects around. Once the map was finished and ready for layout, things got more challenging. The sizing of my map wasn't working and I was unable to figure out how to format the outline to the actual scale of the map. When I tried to make features larger, it was making the box around it larger and not the actual feature, so I was struggling there.
#   - Navigate the software using its GUI
#     - The software to create the maps along with the symbology and data features were easy to learn and use as tools in the process. Navigating the propeties and features in the layout portio with the legend and map layout were very challenging to naviagate with all there drop downs. It had a lot of information, but none which seemed to solve some formating problems.

# %% [markdown]
# ### **Save and share this notebook**
#
# Then I copied [this link](https://www.google.com/url?q=https%3A%2F%2Fdrive.google.com%2Fuc%3Fexport%3Dview%26id%3D1SXPpTnp055ru1Md_GDCsmVZC8QfRC6J-) as my submission to Assignment Week 1

# %% [markdown]
# ### **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
